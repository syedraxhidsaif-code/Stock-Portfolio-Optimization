# %% [markdown]
# # 📈 Stock Portfolio Optimization & Risk Analysis
#
# ## Notebook 01: Data Collection
#
# ### Objective
# Download historical stock price data using Yahoo Finance, inspect the data quality, and save the raw dataset for further analysis.
#
# ### Stocks Analyzed
# - Reliance Industries
# - Infosys
# - TCS
# - SBI
# - LT
# - Bharti Airtel
# - (and other selected stocks)
#
# ### Tools Used
# - Python
# - Pandas
# - NumPy
# - yfinance
# - Matplotlib
# - Jupyter Notebook

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt

# Display settings
pd.set_option("display.max_columns", None)
plt.style.use("ggplot")

# %%
# Section 2 – Define Stock Tickers (NSE)

tickers = [
    "RELIANCE.NS",      # Reliance Industries
    "TCS.NS",           # Tata Consultancy Services
    "HDFCBANK.NS",      # HDFC Bank
    "ICICIBANK.NS",     # ICICI Bank
    "INFY.NS",          # Infosys
    "SBIN.NS",          # State Bank of India
    "LT.NS",            # Larsen & Toubro
    "BHARTIARTL.NS",    # Bharti Airtel
    "ITC.NS",           # ITC
    "HINDUNILVR.NS"     # Hindustan Unilever
]

# %%
data = yf.download(
    tickers,
    start="2021-01-01",
    end=datetime.today().strftime("%Y-%m-%d"),
    auto_adjust=False,
    group_by="ticker"
)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
data.head()
# Out:
# Ticker     RELIANCE.NS                                                  \
# Price             Open        High         Low       Close   Adj Close
# Date
# 2021-01-01  917.461670  921.615173  914.692688  917.230957  897.047058
# 2021-01-04  920.738342  922.492004  908.231689  918.776978  898.559082
# 2021-01-05  908.693176  915.431091  902.693665  907.354858  887.388306
# 2021-01-06  907.262512  907.308655  879.226440  883.426086  863.986145
# 2021-01-07  886.310425  897.617188  879.226440  881.995422  862.586975
#
# Ticker               ICICIBANK.NS                                      \
# Price         Volume         Open        High         Low       Close
# Date
# 2021-01-01  10015175   535.549988  537.000000  526.099976  527.500000
# 2021-01-04  24513534   532.299988  535.000000  524.299988  531.700012
# 2021-01-05  24123091   526.650024  539.950012  523.000000  537.250000
# 2021-01-06  46401468   538.750000  550.599976  535.849976  546.700012
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1402 entries, 2021-01-01 to 2026-08-28
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (RELIANCE.NS, Open)         1402 non-null   float64
#  1   (RELIANCE.NS, High)         1402 non-null   float64
#  2   (RELIANCE.NS, Low)          1402 non-null   float64
#  3   (RELIANCE.NS, Close)        1402 non-null   float64
#  4   (RELIANCE.NS, Adj Close)    1402 non-null   float64
#  5   (RELIANCE.NS, Volume)       1402 non-null   int64
#  6   (ICICIBANK.NS, Open)        1402 non-null   float64
#  7   (ICICIBANK.NS, High)        1402 non-null   float64
#  8   (ICICIBANK.NS, Low)         1402 non-null   float64
#  9   (ICICIBANK.NS, Close)       1402 non-null   float64
#  10  (ICICIBANK.NS, Adj Close)   1402 non-null   float64
#  11  (ICICIBANK.NS, Volume)      1402 non-null   int64
#  12  (TCS.NS, Open)              1402 non-null   float64
# ...

# %%
data.describe()
# Out:
# Ticker  RELIANCE.NS                                                      \
# Price          Open         High          Low        Close    Adj Close
# count   1402.000000  1402.000000  1402.000000  1402.000000  1402.000000
# mean    1247.514119  1258.807383  1235.829337  1246.924142  1232.008526
# std      172.309271   173.038933   171.712369   172.360037   175.459442
# min      858.112793   879.157166   844.544678   850.059631   831.353882
# 25%     1128.794006  1140.760712  1117.400726  1126.890259  1109.356293
# 50%     1234.049988  1244.707520  1222.299988  1234.287537  1219.692017
# 75%     1392.225037  1407.950012  1381.731262  1393.975006  1384.498596
# max     1604.449951  1611.800049  1585.500000  1600.900024  1584.971802
#
# Ticker               ICICIBANK.NS                                         \
# Price         Volume         Open         High          Low        Close
# count   1.402000e+03  1402.000000  1402.000000  1402.000000  1402.000000
# ...

# %%
data.to_csv("../data/raw/stock_data.csv")

print("Data saved successfully!")
# Out:
# Data saved successfully!
