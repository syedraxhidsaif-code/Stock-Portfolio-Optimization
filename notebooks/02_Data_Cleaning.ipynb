# %% [markdown]
# # 📊 Stock Portfolio Optimization & Risk Analysis
#
# ## Notebook 02: Data Cleaning & Quality Checks
#
# ### Objective
# Validate the downloaded stock market data, check for missing values and duplicates, prepare a clean Adjusted Close price dataset, and export it for portfolio analysis.
#
# ### Tasks
# - Load raw stock data
# - Check data quality
# - Handle missing values
# - Check duplicate rows
# - Verify datetime index
# - Extract Adjusted Close prices
# - Export cleaned dataset

# %%
import pandas as pd 
import numpy as np
import os

print(os.getcwd())
# Out:
# d:\stock optimization project\notebooks

# %% [markdown]
# Load Rwa Stock Data

# %%
data = pd.read_csv(
    "../data/raw/stock_data.csv",
    header=[0,1],
    index_col=0,
    parse_dates=True
)

data.head()
# Out:
# Ticker     HINDUNILVR.NS                                                      \
# Price               Open         High          Low        Close    Adj Close
# Date
# 2021-01-01   2395.399902  2404.000000  2382.000000  2387.550049  2173.496094
# 2021-01-04   2405.000000  2430.000000  2400.699951  2426.500000  2208.954102
# 2021-01-05   2405.000000  2456.949951  2405.000000  2450.550049  2230.848145
# 2021-01-06   2445.800049  2450.000000  2401.600098  2417.300049  2200.578613
# 2021-01-07   2432.000000  2432.699951  2365.000000  2368.850098  2156.472900
#
# Ticker                LT.NS                                         ...  \
# Price        Volume    Open         High          Low        Close  ...
# Date                                                                ...
# 2021-01-01   830096  1283.0  1299.949951  1283.000000  1297.000000  ...
# 2021-01-04  1614486  1305.0  1322.550049  1302.000000  1314.599976  ...
# ...

# %% [markdown]
# Basic Information

# %%
print("="*50)
print("Dataset Shape")
print(data.shape)

print("="*50)
print("Dataset Information")
data.info()
# Out:
# ...
# Dataset Shape
# (1236, 60)
# ...
# Dataset Information
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1236 entries, 2021-01-01 to 2025-12-31
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (HINDUNILVR.NS, Open)       1236 non-null   float64
#  1   (HINDUNILVR.NS, High)       1236 non-null   float64
#  2   (HINDUNILVR.NS, Low)        1236 non-null   float64
#  3   (HINDUNILVR.NS, Close)      1236 non-null   float64
#  4   (HINDUNILVR.NS, Adj Close)  1236 non-null   float64
#  5   (HINDUNILVR.NS, Volume)     1236 non-null   int64
#  6   (LT.NS, Open)               1236 non-null   float64
#  7   (LT.NS, High)               1236 non-null   float64
#  8   (LT.NS, Low)                1236 non-null   float64
#  9   (LT.NS, Close)              1236 non-null   float64
#  10  (LT.NS, Adj Close)          1236 non-null   float64
#  11  (LT.NS, Volume)             1236 non-null   int64
# ...

# %% [markdown]
# Missing Value

# %%
missing_values = data.isnull().sum()

print(missing_values)
# Out:
# Ticker         Price
# HINDUNILVR.NS  Open         0
#                High         0
#                Low          0
#                Close        0
#                Adj Close    0
#                Volume       0
# LT.NS          Open         0
#                High         0
#                Low          0
#                Close        0
#                Adj Close    0
#                Volume       0
# INFY.NS        Open         0
#                High         0
#                Low          0
#                Close        0
#                Adj Close    0
#                Volume       0
# HDFCBANK.NS    Open         0
#                High         0
#                Low          0
#                Close        0
#                Adj Close    0
#                Volume       0
# SBIN.NS        Open         0
#                High         0
#                Low          0
#                Close        0
#                Adj Close    0
#                Volume       0
# ...

# %%
print("Total Missing Values:", missing_values.sum())
# Out:
# Total Missing Values: 0

# %% [markdown]
# Duplicates Rwa

# %%
duplicates = data.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %% [markdown]
# Data Types

# %%
print(data.dtypes)
# Out:
# Ticker         Price
# HINDUNILVR.NS  Open         float64
#                High         float64
#                Low          float64
#                Close        float64
#                Adj Close    float64
#                Volume         int64
# LT.NS          Open         float64
#                High         float64
#                Low          float64
#                Close        float64
#                Adj Close    float64
#                Volume         int64
# INFY.NS        Open         float64
#                High         float64
#                Low          float64
#                Close        float64
#                Adj Close    float64
#                Volume         int64
# HDFCBANK.NS    Open         float64
#                High         float64
#                Low          float64
#                Close        float64
#                Adj Close    float64
#                Volume         int64
# SBIN.NS        Open         float64
# ...

# %% [markdown]
# Verify Datetime Index

# %%
print(type(data.index))

print(data.index)
# Out:
# <class 'pandas.DatetimeIndex'>
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14',
#                ...
#                '2025-12-17', '2025-12-18', '2025-12-19', '2025-12-22',
#                '2025-12-23', '2025-12-24', '2025-12-26', '2025-12-29',
#                '2025-12-30', '2025-12-31'],
#               dtype='datetime64[us]', name='Date', length=1236, freq=None)

# %% [markdown]
# Extract Adjusted Close Prices

# %%
adj_close = data.xs("Adj Close", level=1, axis=1)

adj_close.head()
# Out:
# Ticker      HINDUNILVR.NS        LT.NS      INFY.NS  HDFCBANK.NS     SBIN.NS  \
# Date
# 2021-01-01    2173.496094  1218.873169  1086.097046   663.905701  253.242340
# 2021-01-04    2208.954102  1235.412964  1110.052002   659.689453  254.737793
# 2021-01-05    2230.848145  1227.613037  1114.833984   664.674438  255.372299
# 2021-01-06    2200.578613  1234.849121  1104.752319   661.809265  258.363342
# 2021-01-07    2156.472900  1258.296143  1087.562012   659.805969  260.765259
#
# Ticker      RELIANCE.NS  BHARTIARTL.NS  ICICIBANK.NS       TCS.NS      ITC.NS
# Date
# 2021-01-01   897.047058     494.208191    510.191467  2534.896973  159.716614
# 2021-01-04   898.559082     496.078918    514.253601  2631.159668  159.380524
# 2021-01-05   887.388245     493.104950    519.621582  2677.516113  157.924133
# 2021-01-06   863.986084     503.945587    528.761414  2641.590576  153.405640
# 2021-01-07   862.586914     523.084534    523.345154  2625.403564  151.463791

# %% [markdown]
# Rename Columns

# %%
adj_close.columns = [
    col.replace(".NS", "")
    for col in adj_close.columns
]

adj_close.head()
# Out:
#              HINDUNILVR           LT         INFY    HDFCBANK        SBIN  \
# Date
# 2021-01-01  2173.496094  1218.873169  1086.097046  663.905701  253.242340
# 2021-01-04  2208.954102  1235.412964  1110.052002  659.689453  254.737793
# 2021-01-05  2230.848145  1227.613037  1114.833984  664.674438  255.372299
# 2021-01-06  2200.578613  1234.849121  1104.752319  661.809265  258.363342
# 2021-01-07  2156.472900  1258.296143  1087.562012  659.805969  260.765259
#
#               RELIANCE  BHARTIARTL   ICICIBANK          TCS         ITC
# Date
# 2021-01-01  897.047058  494.208191  510.191467  2534.896973  159.716614
# 2021-01-04  898.559082  496.078918  514.253601  2631.159668  159.380524
# 2021-01-05  887.388245  493.104950  519.621582  2677.516113  157.924133
# 2021-01-06  863.986084  503.945587  528.761414  2641.590576  153.405640
# 2021-01-07  862.586914  523.084534  523.345154  2625.403564  151.463791

# %%
adj_close.info()

adj_close.describe()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1236 entries, 2021-01-01 to 2025-12-31
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   HINDUNILVR  1236 non-null   float64
#  1   LT          1236 non-null   float64
#  2   INFY        1236 non-null   float64
#  3   HDFCBANK    1236 non-null   float64
#  4   SBIN        1236 non-null   float64
#  5   RELIANCE    1236 non-null   float64
#  6   BHARTIARTL  1236 non-null   float64
#  7   ICICIBANK   1236 non-null   float64
#  8   TCS         1236 non-null   float64
#  9   ITC         1236 non-null   float64
# dtypes: float64(10)
# memory usage: 106.2 KB
#         HINDUNILVR           LT         INFY     HDFCBANK         SBIN  \
# count  1236.000000  1236.000000  1236.000000  1236.000000  1236.000000
# mean   2324.134159  2561.489259  1432.471855   773.386162   592.628865
# std     181.031214   895.664184   186.306541    97.024789   173.773399
# ...

# %%
import os

os.makedirs("data/processed", exist_ok=True)

import os

os.makedirs("../data/processed", exist_ok=True)

adj_close.to_csv("../data/processed/adjusted_close.csv")
